# %%
import os
import zipfile
import random
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile

# %%
# !wget --no-check-certificate \
    "https://github.com/gitbyandriani/Bangkit-Capstone-Project-C22-PS055/blob/main/BEEF.zip?raw=true"\
    -O "/tmp/BEEF.zip"

local_zip = "/tmp/BEEF.zip"
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2022-05-29 09:02:07--  https://github.com/gitbyandriani/Bangkit-Capstone-Project-C22-PS055/blob/main/BEEF.zip?raw=true
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/gitbyandriani/Bangkit-Capstone-Project-C22-PS055/raw/main/BEEF.zip [following]
# --2022-05-29 09:02:07--  https://github.com/gitbyandriani/Bangkit-Capstone-Project-C22-PS055/raw/main/BEEF.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/gitbyandriani/Bangkit-Capstone-Project-C22-PS055/main/BEEF.zip [following]
# --2022-05-29 09:02:07--  https://media.githubusercontent.com/media/gitbyandriani/Bangkit-Capstone-Project-C22-PS055/main/BEEF.zip
# ...

# %%
source_path = '/tmp/BEEF'

source_path_brisket = os.path.join(source_path, 'brisket')
source_path_chuck = os.path.join(source_path, 'chuck')
source_path_flank = os.path.join(source_path, 'flank')
source_path_plate = os.path.join(source_path, 'plate')
source_path_rib = os.path.join(source_path, 'rib')
source_path_round = os.path.join(source_path, 'round')
source_path_shank = os.path.join(source_path, 'shank')
source_path_short_loin = os.path.join(source_path, 'short_loin')
source_path_sirloin = os.path.join(source_path, 'sirloin')
source_path_tenderloin = os.path.join(source_path, 'tenderloin')


# os.listdir returns a list containing all files under the given path
print(f"There are {len(os.listdir(source_path_brisket))} images of brisket.")
print(f"There are {len(os.listdir(source_path_chuck))} images of chuck.")
print(f"There are {len(os.listdir(source_path_flank))} images of flank.")
print(f"There are {len(os.listdir(source_path_plate))} images of plate.")
print(f"There are {len(os.listdir(source_path_rib))} images of rib.")
print(f"There are {len(os.listdir(source_path_round))} images of round.")
print(f"There are {len(os.listdir(source_path_shank))} images of shank.")
print(f"There are {len(os.listdir(source_path_short_loin))} images of short_loin.")
print(f"There are {len(os.listdir(source_path_sirloin))} images of sirloin.")
print(f"There are {len(os.listdir(source_path_tenderloin))} images of tenderloin.")
# Out:
# There are 300 images of brisket.
# There are 353 images of chuck.
# There are 300 images of flank.
# There are 300 images of plate.
# There are 300 images of rib.
# There are 310 images of round.
# There are 300 images of shank.
# There are 300 images of short_loin.
# There are 300 images of sirloin.
# There are 304 images of tenderloin.

# %%
# Use os.mkdir to create your directories
# You will need a directory for cats-v-dogs, and subdirectories for training
# and testing. These in turn will need subdirectories for 'cats' and 'dogs'

to_create = [
    '/tmp/types-beef-cut',
    '/tmp/types-beef-cut/training',
    '/tmp/types-beef-cut/testing',

    '/tmp/types-beef-cut/training/brisket',
    '/tmp/types-beef-cut/training/chuck',
    '/tmp/types-beef-cut/training/flank',
    '/tmp/types-beef-cut/training/plate',
    '/tmp/types-beef-cut/training/rib',
    '/tmp/types-beef-cut/training/round',
    '/tmp/types-beef-cut/training/rump',
    '/tmp/types-beef-cut/training/shank',
    '/tmp/types-beef-cut/training/short_loin',
    '/tmp/types-beef-cut/training/sirloin',
    '/tmp/types-beef-cut/training/tenderloin',


    '/tmp/types-beef-cut/testing/brisket',
    '/tmp/types-beef-cut/testing/chuck',
    '/tmp/types-beef-cut/testing/flank',
    '/tmp/types-beef-cut/testing/plate',
    '/tmp/types-beef-cut/testing/rib',
    '/tmp/types-beef-cut/testing/round',
    '/tmp/types-beef-cut/testing/rump',
    '/tmp/types-beef-cut/testing/shank',
    '/tmp/types-beef-cut/testing/short_loin',
    '/tmp/types-beef-cut/testing/sirloin',
    '/tmp/types-beef-cut/testing/tenderloin',
]

for directory in to_create:
    try:
        os.mkdir(directory)
        print(directory, 'created')
    except:
        print(directory, 'failed')
# Out:
# /tmp/types-beef-cut created
# /tmp/types-beef-cut/training created
# /tmp/types-beef-cut/testing created
# /tmp/types-beef-cut/training/brisket created
# /tmp/types-beef-cut/training/chuck created
# /tmp/types-beef-cut/training/flank created
# /tmp/types-beef-cut/training/plate created
# /tmp/types-beef-cut/training/rib created
# /tmp/types-beef-cut/training/round created
# /tmp/types-beef-cut/training/rump created
# /tmp/types-beef-cut/training/shank created
# /tmp/types-beef-cut/training/short_loin created
# /tmp/types-beef-cut/training/sirloin created
# /tmp/types-beef-cut/training/tenderloin created
# /tmp/types-beef-cut/testing/brisket created
# /tmp/types-beef-cut/testing/chuck created
# /tmp/types-beef-cut/testing/flank created
# /tmp/types-beef-cut/testing/plate created
# /tmp/types-beef-cut/testing/rib created
# /tmp/types-beef-cut/testing/round created
# /tmp/types-beef-cut/testing/rump created
# /tmp/types-beef-cut/testing/shank created
# ...

# %%
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):


  files = []
  for filename in os.listdir(SOURCE):
    file = SOURCE + filename
    if os.path.getsize(file) > 0:
        files.append(filename)
    else:
        print(filename + " is zero length, so ignoring.")

  training_length = int(len(files) * SPLIT_SIZE)
  testing_length = int(len(files) - training_length)
  shuffled_set = random.sample(files, len(files))
  training_set = shuffled_set[0:training_length]
  testing_set = shuffled_set[:testing_length]

  for filename in training_set:
      this_file = SOURCE + filename
      destination = TRAINING + filename
      copyfile(this_file, destination)

  for filename in testing_set:
      this_file = SOURCE + filename
      destination = TESTING + filename
      copyfile(this_file, destination)

# %%
# Test your split_data function

# Define paths
brisket_SOURCE_DIR = "/tmp/BEEF/brisket/"
chuck_SOURCE_DIR = "/tmp/BEEF/chuck/"
flank_SOURCE_DIR = "/tmp/BEEF/flank/"
plate_SOURCE_DIR = "/tmp/BEEF/plate/"
rib_SOURCE_DIR = "/tmp/BEEF/rib/"
round_SOURCE_DIR = "/tmp/BEEF/round/"
rump_SOURCE_DIR = "/tmp/BEEF/rump/"
shank_SOURCE_DIR = "/tmp/BEEF/shank/"
short_loin_SOURCE_DIR = "/tmp/BEEF/short_loin/"
sirloin_SOURCE_DIR = "/tmp/BEEF/sirloin/"
tenderloin_SOURCE_DIR = "/tmp/BEEF/tenderloin/"

TRAINING_DIR = "/tmp/types-beef-cut/training/"
TESTING_DIR = "/tmp/types-beef-cut/testing/"

TRAINING_brisket_DIR = os.path.join(TRAINING_DIR, "brisket/")
TESTING_brisket_DIR = os.path.join(TESTING_DIR, "brisket/")

TRAINING_chuck_DIR = os.path.join(TRAINING_DIR, "chuck/")
TESTING_chuck_DIR = os.path.join(TESTING_DIR, "chuck/")

TRAINING_flank_DIR = os.path.join(TRAINING_DIR, "flank/")
TESTING_flank_DIR = os.path.join(TESTING_DIR, "flank/")

TRAINING_plate_DIR = os.path.join(TRAINING_DIR, "plate/")
TESTING_plate_DIR = os.path.join(TESTING_DIR, "plate/")

TRAINING_rib_DIR = os.path.join(TRAINING_DIR, "rib/")
TESTING_rib_DIR = os.path.join(TESTING_DIR, "rib/")

TRAINING_round_DIR = os.path.join(TRAINING_DIR, "round/")
TESTING_round_DIR = os.path.join(TESTING_DIR, "round/")

TRAINING_rump_DIR = os.path.join(TRAINING_DIR, "rump/")
TESTING_rump_DIR = os.path.join(TESTING_DIR, "rump/")

TRAINING_shank_DIR = os.path.join(TRAINING_DIR, "shank/")
TESTING_shank_DIR = os.path.join(TESTING_DIR, "shank/")

TRAINING_short_loin_DIR = os.path.join(TRAINING_DIR, "short_loin/")
TESTING_short_loin_DIR = os.path.join(TESTING_DIR, "short_loin/")

TRAINING_sirloin_DIR = os.path.join(TRAINING_DIR, "sirloin/")
TESTING_sirloin_DIR = os.path.join(TESTING_DIR, "sirloin/")

TRAINING_tenderloin_DIR = os.path.join(TRAINING_DIR, "tenderloin/")
TESTING_tenderloin_DIR = os.path.join(TESTING_DIR, "tenderloin/")

# Empty directories in case you run this cell multiple times
if len(os.listdir(TRAINING_brisket_DIR)) > 0:
  for file in os.scandir(TRAINING_brisket_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_chuck_DIR)) > 0:
  for file in os.scandir(TRAINING_chuck_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_flank_DIR)) > 0:
  for file in os.scandir(TRAINING_flank_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_plate_DIR)) > 0:
  for file in os.scandir(TRAINING_plate_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_rib_DIR)) > 0:
  for file in os.scandir(TRAINING_rib_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_round_DIR)) > 0:
  for file in os.scandir(TRAINING_round_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_rump_DIR)) > 0:
  for file in os.scandir(TRAINING_rump_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_shank_DIR)) > 0:
  for file in os.scandir(TRAINING_shank_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_short_loin_DIR)) > 0:
  for file in os.scandir(TRAINING_short_loin_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_sirloin_DIR)) > 0:
  for file in os.scandir(TRAINING_sirloin_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_tenderloin_DIR)) > 0:
  for file in os.scandir(TRAINING_tenderloin_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_brisket_DIR)) > 0:
  for file in os.scandir(TESTING_brisket_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_chuck_DIR)) > 0:
  for file in os.scandir(TESTING_chuck_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_flank_DIR)) > 0:
  for file in os.scandir(TESTING_flank_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_plate_DIR)) > 0:
  for file in os.scandir(TESTING_plate_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_rib_DIR)) > 0:
  for file in os.scandir(TESTING_rib_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_round_DIR)) > 0:
  for file in os.scandir(TESTING_round_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_rump_DIR)) > 0:
  for file in os.scandir(TESTING_rump_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_shank_DIR)) > 0:
  for file in os.scandir(TESTING_shank_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_short_loin_DIR)) > 0:
  for file in os.scandir(TESTING_short_loin_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_sirloin_DIR)) > 0:
  for file in os.scandir(TESTING_sirloin_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_tenderloin_DIR)) > 0:
  for file in os.scandir(TESTING_tenderloin_DIR):
    os.remove(file.path)
# Define proportion of images used for training
split_size = .9

# Run the function
# NOTE: Messages about zero length images should be printed out
split_data(brisket_SOURCE_DIR, TRAINING_brisket_DIR, TESTING_brisket_DIR, split_size)
split_data(chuck_SOURCE_DIR, TRAINING_chuck_DIR, TESTING_chuck_DIR, split_size)
split_data(flank_SOURCE_DIR, TRAINING_flank_DIR, TESTING_flank_DIR, split_size)
split_data(plate_SOURCE_DIR, TRAINING_plate_DIR, TESTING_plate_DIR, split_size)
split_data(rib_SOURCE_DIR, TRAINING_rib_DIR, TESTING_rib_DIR, split_size)
split_data(chuck_SOURCE_DIR, TRAINING_chuck_DIR, TESTING_chuck_DIR, split_size)
split_data(round_SOURCE_DIR, TRAINING_round_DIR, TESTING_round_DIR, split_size)
split_data(rump_SOURCE_DIR, TRAINING_rump_DIR, TESTING_rump_DIR, split_size)
split_data(shank_SOURCE_DIR, TRAINING_shank_DIR, TESTING_shank_DIR, split_size)
split_data(short_loin_SOURCE_DIR, TRAINING_short_loin_DIR, TESTING_short_loin_DIR, split_size)
split_data(sirloin_SOURCE_DIR, TRAINING_sirloin_DIR, TESTING_sirloin_DIR, split_size)
split_data(tenderloin_SOURCE_DIR, TRAINING_tenderloin_DIR, TESTING_tenderloin_DIR, split_size)

# Check that the number of images matches the expected output
print(f"\n\nThere are {len(os.listdir(TRAINING_brisket_DIR))} images of brisket for training")
print(f"There are {len(os.listdir(TRAINING_chuck_DIR))} images of chuck for training")
print(f"There are {len(os.listdir(TRAINING_flank_DIR))} images of flank for training")
print(f"There are {len(os.listdir(TRAINING_plate_DIR))} images of plate for training")
print(f"There are {len(os.listdir(TRAINING_rib_DIR))} images of rib for training")
print(f"There are {len(os.listdir(TRAINING_round_DIR))} images of round for training")
print(f"There are {len(os.listdir(TRAINING_rump_DIR))} images of rump for training")
print(f"There are {len(os.listdir(TRAINING_shank_DIR))} images of shank for training")
print(f"There are {len(os.listdir(TRAINING_short_loin_DIR))} images of short_loin for training")
print(f"There are {len(os.listdir(TRAINING_sirloin_DIR))} images of sirloin for training")
print(f"There are {len(os.listdir(TRAINING_tenderloin_DIR))} images of tenderloin for training")
print(f"There are {len(os.listdir(TESTING_brisket_DIR))} images of brisket for testing")
print(f"There are {len(os.listdir(TESTING_chuck_DIR))} images of chuck for testing")
print(f"There are {len(os.listdir(TESTING_flank_DIR))} images of flank for testing")
print(f"There are {len(os.listdir(TESTING_plate_DIR))} images of plate for testing")
print(f"There are {len(os.listdir(TESTING_rib_DIR))} images of rib for testing")
print(f"There are {len(os.listdir(TESTING_round_DIR))} images of round for testing")
print(f"There are {len(os.listdir(TESTING_rump_DIR))} images of rump for testing")
print(f"There are {len(os.listdir(TESTING_shank_DIR))} images of shank for testing")
print(f"There are {len(os.listdir(TESTING_short_loin_DIR))} images of short_loin for testing")
print(f"There are {len(os.listdir(TESTING_sirloin_DIR))} images of sirloin for testing")
print(f"There are {len(os.listdir(TESTING_tenderloin_DIR))} images of tenderloin for testing")
# Out:
# There are 270 images of brisket for training
# There are 350 images of chuck for training
# There are 270 images of flank for training
# There are 270 images of plate for training
# There are 270 images of rib for training
# There are 279 images of round for training
# There are 352 images of rump for training
# There are 270 images of shank for training
# There are 270 images of short_loin for training
# There are 270 images of sirloin for training
# There are 273 images of tenderloin for training
# There are 30 images of brisket for testing
# There are 70 images of chuck for testing
# There are 30 images of flank for testing
# There are 30 images of plate for testing
# There are 30 images of rib for testing
# There are 31 images of round for testing
# There are 40 images of rump for testing
# There are 30 images of shank for testing
# There are 30 images of short_loin for testing
# There are 30 images of sirloin for testing
# There are 31 images of tenderloin for testing

# %%
# GRADED FUNCTION: train_val_generators
def train_val_generators(TRAINING_DIR, VALIDATION_DIR):
  ### START CODE HERE
  TRAINING_DIR =  "/tmp/types-beef-cut/training"
  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  train_datagen = ImageDataGenerator(
        rescale=1.0/255.,
        rotation_range=90,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

  # Pass in the appropiate arguments to the flow_from_directory method
  train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                      batch_size=50,
                                                      class_mode='categorical',
                                                      target_size=(225, 225))

  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  VALIDATION_DIR = "/tmp/types-beef-cut/testing"
  validation_datagen = ImageDataGenerator(
        rescale=1.0/255.,
        rotation_range=90,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

  # Pass in the appropiate arguments to the flow_from_directory method
  validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                                batch_size=30,
                                                                class_mode='categorical',
                                                                target_size=(225, 225))
  return train_generator, validation_generator

# %%
# Test your generators
train_generator, validation_generator = train_val_generators(TRAINING_DIR, TESTING_DIR)
# Out:
# Found 3144 images belonging to 11 classes.
# Found 382 images belonging to 11 classes.

# %%
# GRADED FUNCTION: create_model
def create_model():
  # DEFINE A KERAS MODEL TO CLASSIFY BEEF CUT
  # USE AT LEAST 3 CONVOLUTION LAYERS

  ### START CODE HERE

  model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(225, 225, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(128, activation='relu'), 
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(11, activation='softmax')
  ])

  model.compile(optimizer='adam', loss ='categorical_crossentropy', metrics=['accuracy'])
  ### END CODE HERE

  return model

# %%
import warnings
warnings.filterwarnings('ignore')
print('warnings ignored')
# Out:
# warnings ignored

# %%
# Get the untrained model
model = create_model()

# Train the model
# Note that this may take some time.
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=120,
                    verbose=1)
# Out:
# Epoch 1/120
# 63/63 [==============================] - 187s 3s/step - loss: 2.4697 - accuracy: 0.1101 - val_loss: 2.3850 - val_accuracy: 0.1047
# Epoch 2/120
# 63/63 [==============================] - 184s 3s/step - loss: 2.3104 - accuracy: 0.1638 - val_loss: 2.2342 - val_accuracy: 0.2094
# Epoch 3/120
# 63/63 [==============================] - 186s 3s/step - loss: 2.1998 - accuracy: 0.1988 - val_loss: 2.0300 - val_accuracy: 0.2670
# Epoch 4/120
# 63/63 [==============================] - 185s 3s/step - loss: 2.0744 - accuracy: 0.2522 - val_loss: 1.9330 - val_accuracy: 0.3010
# Epoch 5/120
# 63/63 [==============================] - 184s 3s/step - loss: 1.9735 - accuracy: 0.2786 - val_loss: 1.8387 - val_accuracy: 0.2984
# Epoch 6/120
# 63/63 [==============================] - 184s 3s/step - loss: 1.8920 - accuracy: 0.3053 - val_loss: 1.8673 - val_accuracy: 0.3325
# Epoch 7/120
# ...

# %%
# saving and loading the .h5 model
 
# save model
model.save_weights('beef.h5')
print('Model Saved!')
 
# load model
savedModel = model.load_weights('beef.h5')
print('Model Loaded!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2281c0e9cf69> in <module>()
#       2
#       3 # save model
# ----> 4 model.save_weights('beef.h5')
#       5 print('Model Saved!')
#       6
#
# NameError: name 'model' is not defined

# %%
def download_history():
  import pickle
  from google.colab import files

  with open('history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

  files.download('history.pkl')

download_history()
